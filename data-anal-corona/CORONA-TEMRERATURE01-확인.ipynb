# %%
import pandas as pd

# %%
df = pd.read_csv('corona_Temperatures/busan.csv', encoding='UTF-8',parse_dates=['날짜'], dayfirst=True,infer_datetime_format=True)

# %%
df
# Out:
#      Unnamed: 0         날짜 region  confirmed  death  부산일일확진자  부산일일사망자   사망률  \
# 0             0 2020-02-17     부산          0      0        0        0  0.00
# 1             1 2020-02-18     부산          0      0        0        0  0.00
# 2             2 2020-02-19     부산          0      0        0        0  0.00
# 3             3 2020-02-20     부산          8      0        8        0  0.00
# 4             4 2020-02-21     부산          8      0        0        0  0.00
# ..          ...        ...    ...        ...    ...      ...      ...   ...
# 495         495 2021-06-26     부산       6148    124       31        0  2.02
# 496         496 2021-06-27     부산       6160    124       12        0  2.01
# 497         497 2021-06-28     부산       6198    124       38        0  2.00
# 498         498 2021-06-29     부산       6207    124        9        0  2.00
# 499         499 2021-06-30     부산       6221    124       14        0  1.99
#
#      부산 평균기온(℃)
# 0           0.1
# 1           1.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   날짜          500 non-null    datetime64[ns]
#  2   region      500 non-null    object
#  3   confirmed   500 non-null    int64
#  4   death       500 non-null    int64
#  5   부산일일확진자     500 non-null    int64
#  6   부산일일사망자     500 non-null    int64
#  7   사망률         500 non-null    float64
#  8   부산 평균기온(℃)  500 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(1)
# memory usage: 35.3+ KB

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-eb0e90c65406> in <module>
# ----> 1 df.drop('Unnamed: 0', axis=1, inplace=True)
#
# D:\Anaconda\envs\data-anal-corona\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4313             level=level,
#    4314             inplace=inplace,
# -> 4315             errors=errors,
#    4316         )
#    4317
#
# D:\Anaconda\envs\data-anal-corona\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df
# Out:
#             날짜 region  confirmed  death  부산일일확진자  부산일일사망자   사망률  부산 평균기온(℃)
# 0   2020-02-17     부산          0      0        0        0  0.00         0.1
# 1   2020-02-18     부산          0      0        0        0  0.00         1.2
# 2   2020-02-19     부산          0      0        0        0  0.00         6.1
# 3   2020-02-20     부산          8      0        8        0  0.00         9.3
# 4   2020-02-21     부산          8      0        0        0  0.00        11.0
# ..         ...    ...        ...    ...      ...      ...   ...         ...
# 495 2021-06-26     부산       6148    124       31        0  2.02        23.0
# 496 2021-06-27     부산       6160    124       12        0  2.01        23.8
# 497 2021-06-28     부산       6198    124       38        0  2.00        24.1
# 498 2021-06-29     부산       6207    124        9        0  2.00        23.5
# 499 2021-06-30     부산       6221    124       14        0  1.99        23.9
#
# [500 rows x 8 columns]

# %%
df = pd.read_csv('corona_Temperatures/seoul.csv', encoding='UTF-8',parse_dates=['날짜'], dayfirst=True,infer_datetime_format=True)

# %%
df
# Out:
#      Unnamed: 0         날짜 region  confirmed  death  서울일일확진자  서울일일사망자   사망률  \
# 0             0 2020-02-17     서울         14      0        0        0  0.00
# 1             1 2020-02-18     서울         14      0        0        0  0.00
# 2             2 2020-02-19     서울         15      0        1        0  0.00
# 3             3 2020-02-20     서울         22      0        7        0  0.00
# 4             4 2020-02-21     서울         27      0        5        0  0.00
# ..          ...        ...    ...        ...    ...      ...      ...   ...
# 495         495 2021-06-26     서울      48980    512      263        1  1.05
# 496         496 2021-06-27     서울      49222    512      242        0  1.04
# 497         497 2021-06-28     서울      49407    513      185        1  1.04
# 498         498 2021-06-29     서울      49612    513      205        0  1.03
# 499         499 2021-06-30     서울      49987    513      375        0  1.03
#
#      서울 평균기온(℃)
# 0          -5.9
# 1          -4.1
# ...

# %%
df = pd.read_csv('corona_Temperatures/chungbuk.csv', encoding='UTF-8',parse_dates=['날짜'], dayfirst=True,infer_datetime_format=True)

# %%
df
# Out:
#      Unnamed: 0         날짜 region  confirmed  death  충북일일확진자  충북일일사망자   사망률  \
# 0             0 2020-02-17     충북          0      0        0        0  0.00
# 1             1 2020-02-18     충북          0      0        0        0  0.00
# 2             2 2020-02-19     충북          0      0        0        0  0.00
# 3             3 2020-02-20     충북          0      0        0        0  0.00
# 4             4 2020-02-21     충북          1      0        1        0  0.00
# ..          ...        ...    ...        ...    ...      ...      ...   ...
# 495         495 2021-06-26     충북       3282     70        5        0  2.13
# 496         496 2021-06-27     충북       3286     70        4        0  2.13
# 497         497 2021-06-28     충북       3291     70        5        0  2.13
# 498         498 2021-06-29     충북       3301     70       10        0  2.12
# 499         499 2021-06-30     충북       3306     70        5        0  2.12
#
#      충북 평균기온(℃)
# 0          -4.6
# 1          -3.4
# ...

# %%
df = pd.read_csv('corona_Temperatures/jeonnam.csv', encoding='UTF-8',parse_dates=['날짜'], dayfirst=True,infer_datetime_format=True)

# %%
df
# Out:
#      Unnamed: 0         날짜 region  confirmed  death  전남일일확진자  전남일일사망자   사망률  \
# 0             0 2020-02-17     전남          1      0        0        0  0.00
# 1             1 2020-02-18     전남          1      0        0        0  0.00
# 2             2 2020-02-19     전남          1      0        0        0  0.00
# 3             3 2020-02-20     전남          1      0        0        0  0.00
# 4             4 2020-02-21     전남          1      0        0        0  0.00
# ..          ...        ...    ...        ...    ...      ...      ...   ...
# 495         495 2021-06-26     전남       1629     15        3        0  0.92
# 496         496 2021-06-27     전남       1635     15        6        0  0.92
# 497         497 2021-06-28     전남       1637     15        2        0  0.92
# 498         498 2021-06-29     전남       1641     15        4        0  0.91
# 499         499 2021-06-30     전남       1648     15        7        0  0.91
#
#      전남 평균기온(℃)
# 0          -6.6
# 1          -5.1
# ...

# %%
df = pd.read_csv('corona_Temperatures/gangwon.csv', encoding='UTF-8',index_col=0,parse_dates=['날짜'], dayfirst=True,infer_datetime_format=True)

# %%
df
# Out:
#             날짜 region  confirmed  death  강원일일확진자  강원일일사망자   사망률  강원 평균기온(℃)
# 0   2020-02-17     강원          0      0        0        0  0.00       -3.65
# 1   2020-02-18     강원          0      0        0        0  0.00       -1.85
# 2   2020-02-19     강원          0      0        0        0  0.00        1.65
# 3   2020-02-20     강원          1      0        1        0  0.00        4.45
# 4   2020-02-21     강원          1      0        0        0  0.00        6.45
# ..         ...    ...        ...    ...      ...      ...   ...         ...
# 495 2021-06-26     강원       3500     52       35        0  1.49       20.75
# 496 2021-06-27     강원       3519     52       19        0  1.48       22.65
# 497 2021-06-28     강원       3536     53       17        1  1.50       22.45
# 498 2021-06-29     강원       3544     53        8        0  1.50       22.75
# 499 2021-06-30     강원       3559     53       15        0  1.49       22.50
#
# [500 rows x 8 columns]

# %%
import platform
from matplotlib import font_manager, rc # Runtime Configuration
path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import pandas as pd

# %%
df = pd.read_csv('data/202005.csv', index_col=0, encoding='UTF-8')

# %%
df
# Out:
#             지역     망 측정소명  PM10  PM25                         주소  \
# 0        서울 중구  도시대기   중구  34.0  25.0              서울 중구 덕수궁길 15
# 1        서울 중구  도시대기   중구  37.0  26.0              서울 중구 덕수궁길 15
# 2        서울 중구  도시대기   중구  38.0  29.0              서울 중구 덕수궁길 15
# 3        서울 중구  도시대기   중구  43.0  31.0              서울 중구 덕수궁길 15
# 4        서울 중구  도시대기   중구  43.0  33.0              서울 중구 덕수궁길 15
# ...        ...   ...  ...   ...   ...                        ...
# 331819  인천 옹진군  도시대기   영흥  31.0  24.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 331820  인천 옹진군  도시대기   영흥  32.0  24.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 331821  인천 옹진군  도시대기   영흥  34.0  28.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 331822  인천 옹진군  도시대기   영흥  29.0  22.0  인천광역시 옹진군 영흥면 영흥로251번길 90
# 331823  인천 옹진군  도시대기   영흥  22.0  21.0  인천광역시 옹진군 영흥면 영흥로251번길 90
#
#                        date
# 0       2020-05-01 01:00:00
# 1       2020-05-01 02:00:00
# 2       2020-05-01 03:00:00
# 3       2020-05-01 04:00:00
# 4       2020-05-01 05:00:00
# ...

# %%
df['지역']
